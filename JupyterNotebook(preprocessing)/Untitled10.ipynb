# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv")
# Out:
# C:\Users\nana-\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (17,18,20,21,22,23,29,30,31,32,36,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1283294138  GBB9093                 NY        PAS  08/04/2013
# 1      1283294151  62416MB                 NY        COM  08/04/2013
# 2      1283294163  78755JZ                 NY        COM  08/05/2013
# 3      1283294175  63009MA                 NY        COM  08/05/2013
# 4      1283294187  91648MC                 NY        COM  08/08/2013
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0              46              SUBN         AUDI              P         37250
# 1              46               VAN         FORD              P         37290
# 2              46               P-U        CHEVR              P         37030
# 3              46               VAN         FORD              P         37270
# 4              41              TRLR          GMC              P         37240
#
#    ...  Hydrant Violation  Double Parking Violation  Latitude  Longitude  \
# 0  ...                NaN                       NaN       NaN        NaN
# 1  ...                NaN                       NaN       NaN        NaN
# 2  ...                NaN                       NaN       NaN        NaN
# 3  ...                NaN                       NaN       NaN        NaN
# 4  ...                NaN                       NaN       NaN        NaN
#
#    Community Board  Community Council   Census Tract BIN BBL NTA
# 0              NaN                 NaN           NaN NaN NaN NaN
# 1              NaN                 NaN           NaN NaN NaN NaN
# 2              NaN                 NaN           NaN NaN NaN NaN
# 3              NaN                 NaN           NaN NaN NaN NaN
# 4              NaN                 NaN           NaN NaN NaN NaN
#
# [5 rows x 51 columns]

# %%
df = df[['Summons Number','Plate ID','Registration State','Plate Type','Issue Date','Violation Code','Vehicle Body Type','Vehicle Make','Vehicle Expiration Date','Violation Time','Vehicle Color','Vehicle Year','Latitude','Longitude']]

# %%
df = df.sample(n=10000)

# %%
import random
def randpart():
    rand = random.uniform(0, 1)
    if (rand>0.75): 
        return 1
    else :
        return 0

# %%
lst = [randpart() for i in range(0,df.shape[0])]

# %%
df2 = pd.DataFrame(lst)

# %%
df2= df2.rename(columns={'0': 'Alert'})

# %%
df2.columns = ['Alert']

# %%
df = df.reset_index()

# %%
df = df.drop(columns='index')

# %%
df1 = pd.merge(df, df2, left_index=True, right_index=True)

# %%
droneid = ['1','2','3','4']

# %%
random.choice(droneid)
# Out:
# 'Drone3'

# %%
df1['DroneID']= ""

# %%
for index, row in df1.iterrows():
    df1['DroneID'][index] = random.choice(droneid)
# Out:
# C:\Users\nana-\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1.head()
# Out:
#    Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 0      1358899228   35212MB                 NY        COM  12/11/2013
# 1      7227178810  T463515C                 NY        OMT  11/22/2013
# 2      7637505650   FCE5874                 NY        PAS  06/14/2014
# 3      7002978913   GKB7237                 NY        PAS  12/26/2013
# 4      7632730667   46833BA                 NY        OMR  02/08/2014
#
#    Violation Code Vehicle Body Type Vehicle Make  Vehicle Expiration Date  \
# 0              46              DELV        FRUEH                        0
# 1              21              4DSD        LINCO                 20140630
# 2              40              PICK        TOYOT                 20160616
# 3              21              SUBN        TOYOT                 20150918
# 4              77               BUS         STAR                 20140228
#
#   Violation Time Vehicle Color  Vehicle Year  Latitude  Longitude  Alert  \
# 0          0453P         BROWN        2012.0       NaN        NaN      0
# 1          1219P            BK        2006.0       NaN        NaN      0
# 2          1214P            GY        2011.0       NaN        NaN      0
# 3          0927A            BK        2010.0       NaN        NaN      0
# 4          0819A            WH        2007.0       NaN        NaN      0
#
#   DroneID
# 0  Drone2
# 1  Drone1
# 2  Drone2
# 3  Drone1
# 4  Drone2

# %%
for index, row in df1.iterrows():
    df1['Latitude'][index] = random.uniform(40.5,41)
    df1['Longitude'][index] = random.uniform(-74.5,-74)
# Out:
# C:\Users\nana-\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\nana-\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df1
# Out:
#       Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 0         1358899228   35212MB                 NY        COM  12/11/2013
# 1         7227178810  T463515C                 NY        OMT  11/22/2013
# 2         7637505650   FCE5874                 NY        PAS  06/14/2014
# 3         7002978913   GKB7237                 NY        PAS  12/26/2013
# 4         7632730667   46833BA                 NY        OMR  02/08/2014
# 5         7143591919   FMS3532                 NY        PAS  06/24/2014
# 6         7225158144   63544MC                 NY        COM  06/20/2014
# 7         7856303244   ACI7583                 GA        PAS  04/04/2014
# 8         7898885867   97704JW                 NY        COM  08/23/2013
# 9         7095535929   85724JB                 NY        COM  10/09/2013
# 10        7091367273   FLM9911                 NY        PAS  02/12/2014
# 11        1366091700   92443JY                 NY        COM  01/23/2014
# 12        7977357677    Z922HM                 NY        PAS  09/05/2013
# 13        7632758148   CLV3419                 NY        PAS  06/09/2014
# 14        5072719388   CEB4051                 NY        PAS  02/12/2014
# 15        7501835299  T514698C                 NY        OMT  09/17/2013
# 16        7553536878   41986JZ                 NY        COM  04/08/2014
# 17        7078913590   ENM2379                 NY        PAS  03/06/2014
# 18        1354917017   FZB1740                 NY        PAS  11/22/2013
# 19        1355664263   CGR9851                 NY        PAS  08/17/2013
# 20        7930763560    E35BWZ                 NJ        PAS  01/10/2014
# 21        7568799967   FAB9758                 NY        PAS  04/08/2014
# 22        7020076397   FTG8021                 NY        PAS  10/10/2013
# 23        7476366578   R194039                 IL        PAS  04/29/2014
# 24        7582320529   AYW5493                 NY        PAS  05/31/2014
# 25        7250773793   GJP9640                 NY        PAS  01/28/2014
# 26        7884140469     90488                 NY        MED  04/21/2014
# 27        7831160840  T643951C                 NY        OMT  05/04/2014
# 28        5072020782   WXH9690                 VA        PAS  12/12/2013
# 29        7092274503   DJX7288                 NY        PAS  08/25/2013
# ...              ...       ...                ...        ...         ...
# 9970      7967510446    XZ973J                 NJ        PAS  10/09/2013
# 9971      7714298935   DVK2285                 NY        PAS  02/27/2014
# 9972      7062508380   FZK2257                 NY        PAS  11/22/2013
# 9973      7542364455    ZPX16X                 NJ        PAS  11/15/2013
# 9974      7243966792   GJG4722                 NY        PAS  01/23/2014
# 9975      4600164210  BENJI100                 NY        SRF  04/04/2014
# 9976      5072029360   DLG9335                 NY        PAS  12/12/2013
# 9977      7071093386   FFZ1459                 NY        PAS  05/31/2014
# 9978      5073431145   EEH2012                 NY        PAS  05/04/2014
# 9979      7065822977    XY778K                 NJ        PAS  01/02/2014
# 9980      7217598692   57839MD                 NY        COM  05/01/2014
# 9981      7570369026   DVE4801                 NY        PAS  10/07/2013
# 9982      8000007320   FHL3615                 NY        PAS  04/19/2014
# 9983      7703458960   FEY3510                 NY        PAS  10/11/2013
# 9984      7015509398    3974CL                 CT        CMB  06/02/2014
# 9985      7947999326   40363JX                 NY        COM  10/07/2013
# 9986      1364988586   DJG5806                 NY        PAS  04/03/2014
# 9987      7064913173   FFZ3928                 NY        PAS  07/29/2013
# 9988      7786275836   2121865                 ME        PAS  08/09/2013
# 9989      1362275402    UUV65H                 NJ        PAS  03/17/2014
# 9990      7087292810   GCM2354                 NY        PAS  09/11/2013
# 9991      7522347981   GLN3642                 NY        PAS  04/18/2014
# 9992      5070461564   GGN5002                 NY        PAS  09/02/2013
# 9993      7774734910    J45DGR                 NJ        PAS  11/07/2013
# 9994      7984964658   68684JV                 NY        COM  05/05/2014
# 9995      7786782138   GDT1512                 NY        PAS  11/11/2013
# 9996      1367987908    XS372A                 NJ        PAS  04/08/2014
# 9997      5073279438   BPR1267                 NY        PAS  04/12/2014
# 9998      7712645231   DJA1949                 NY        PAS  08/29/2013
# 9999      7728745141   GPK3196                 NY        PAS  06/18/2014
#
#       Violation Code Vehicle Body Type Vehicle Make  Vehicle Expiration Date  \
# 0                 46              DELV        FRUEH                        0
# 1                 21              4DSD        LINCO                 20140630
# 2                 40              PICK        TOYOT                 20160616
# 3                 21              SUBN        TOYOT                 20150918
# 4                 77               BUS         STAR                 20140228
# 5                 83              SUBN         FORD                 20150619
# 6                 19              DELV        ISUZU                 88888888
# 7                 69              T/CR        FRUEH                 20090288
# 8                 69              PICK        CHEVR                 20141130
# 9                 69               VAN          GMC                 20150731
# 10                68              4DSD        TOYOT                 20150328
# 11                46              DELV        MERCU                 20140331
# 12                40              SUBN        MAZDA                 20150607
# 13                21              4DSD        HONDA                 20150514
# 14                 7               NaN        TOYOT                        0
# 15                38              SUBN        CHEVR                 20131031
# 16                38               VAN        CHEVR                 88888888
# 17                20              SUBN         FORD                 20141230
# 18                38               SDN        DODGE                 20140430
# 19                67               SDN          KIA                 20141226
# 20                37              SUBN        LEXUS                 88888888
# 21                21              SUBN         FORD                 20140616
# 22                21              PICK         FORD                 20140124
# 23                37              SUBN        DODGE                 20131288
# 24                21              SUBN        LEXUS                 20160411
# 25                38              4DSD        NISSA                 20151124
# 26                20              2DSD        NS/OT                 20141130
# 27                14              4DSD        TOYOT                 20141130
# 28                 7                4D        DODGE                        0
# 29                72              SUBN        TOYOT                 20140221
# ...              ...               ...          ...                      ...
# 9970              16               VAN         FORD                 88880601
# 9971              21              SUBN        SUBAR                 20140421
# 9972              38              SUBN         AUDI                 20140627
# 9973              17               VAN        DODGE                 88888888
# 9974              24              PICK        DODGE                 20151209
# 9975              36              4DSD          BMW                        0
# 9976               7              SUBN         FORD                        0
# 9977              37              2DSD          BMW                 20160110
# 9978               7              SUBN        LEXUS                        0
# 9979              38              DELV           UD                 20140088
# 9980              37              PICK         FORD                 20150531
# 9981              21              4DSD          BMW                 20141006
# 9982              38              SUBN        TOYOT                 20150106
# 9983              21              4DSD        HONDA                 20140822
# 9984              38               VAN         FORD                 20140088
# 9985              69               VAN         FORD                 20140228
# 9986              21               SDN        HONDA                 20150821
# 9987              21              4DSD        LEXUS                 20150123
# 9988              66              TRLR        NS/OT                 88880088
# 9989              60              SUBN         JEEP                        0
# 9990              21              SUBN        INFIN                 20141216
# 9991              40              SUBN         FORD                 20151201
# 9992               7              SUBN        HYUND                        0
# 9993              46              SUBN         JEEP                 88888888
# 9994              40              DELV        INTER                 20141130
# 9995              38              4DSD        CADIL                 20141129
# 9996              46              DELV        FT/LI                        0
# 9997               7              4DSD        HONDA                        0
# 9998              38              SUBN        CHEVR                 20140405
# 9999              70              SUBN         JEEP                 20140616
#
#      Violation Time Vehicle Color  Vehicle Year   Latitude  Longitude  Alert  \
# 0             0453P         BROWN        2012.0  40.608454 -74.166999      0
# 1             1219P            BK        2006.0  40.889344 -74.477772      0
# 2             1214P            GY        2011.0  40.548850 -74.367283      0
# 3             0927A            BK        2010.0  40.543583 -74.454780      0
# 4             0819A            WH        2007.0  40.580227 -74.365845      0
# 5             1030A         WHITE        2001.0  40.523315 -74.050995      0
# 6             0233P         BROWN        2012.0  40.991973 -74.464042      0
# 7             0125P         WHITE           0.0  40.874331 -74.071226      0
# 8             0513P         WHITE        2009.0  40.904538 -74.275283      0
# 9             1017A            WH        1995.0  40.646015 -74.329486      0
# 10            0308P            GY        2007.0  40.551405 -74.479989      1
# 11            1145A            WH        2010.0  40.529862 -74.443443      0
# 12            0906A            GY        2005.0  40.840468 -74.378578      0
# 13            1143A            GY        2003.0  40.544858 -74.168930      0
# 14            0328P            BL        2003.0  40.789001 -74.481440      0
# 15            1220P            BK        2008.0  40.851768 -74.237934      1
# 16            1212P         WHITE        2009.0  40.991077 -74.322343      0
# 17            0522P            BK        1999.0  40.971161 -74.481744      0
# 18            0248A           WHT        2008.0  40.526388 -74.412165      0
# 19            0953A            GY        2012.0  40.714107 -74.143616      0
# 20            1220P         WHITE           0.0  40.649576 -74.093236      0
# 21            0812A            BL        2002.0  40.500702 -74.393266      0
# 22            0919A            WH        1995.0  40.691569 -74.484340      0
# 23            0108P           RED           0.0  40.856967 -74.419660      1
# 24            0810A            TN        2005.0  40.899194 -74.355502      1
# 25            0118P            GY           0.0  40.686307 -74.177341      1
# 26            0548P           RED        2007.0  40.675466 -74.123636      0
# 27            1223P            BK        2014.0  40.840212 -74.088040      0
# 28            0737A           RED        2010.0  40.721300 -74.261807      0
# 29            1104A            BL        2004.0  40.814409 -74.478339      0
# ...             ...           ...           ...        ...        ...    ...
# 9970          1043A         WHITE           0.0  40.766049 -74.462726      0
# 9971          0025A            GR        2011.0  40.877853 -74.155074      1
# 9972          0444P            BK        2012.0  40.923909 -74.401866      0
# 9973          0551P         WHITE           0.0  40.843049 -74.039294      0
# 9974          1035A            RD        2005.0  40.550509 -74.222538      0
# 9975          1046A            GY        2002.0  40.867369 -74.298815      1
# 9976          0602P            GY        2011.0  40.835398 -74.161693      0
# 9977          0609P            GY        2013.0  40.769820 -74.414188      1
# 9978          1007A            GY        2014.0  40.594822 -74.340192      0
# 9979          0917A         WHITE           0.0  40.660375 -74.081152      0
# 9980          0127P            BL        2006.0  40.679008 -74.021006      0
# 9981          0930A            BK        2004.0  40.786310 -74.020664      1
# 9982          0141P            GL        1998.0  40.788322 -74.162422      0
# 9983          0857A            BK        2012.0  40.762421 -74.377466      0
# 9984          0850A         BLACK           0.0  40.981214 -74.440308      0
# 9985          0755A            WH        2008.0  40.530751 -74.155395      0
# 9986          0944A            GY        2013.0  40.641903 -74.056618      1
# 9987          1010A         WHITE        1996.0  40.614268 -74.223770      1
# 9988          0131P           RED           0.0  40.777646 -74.447712      0
# 9989          1022P         BLACK           0.0  40.875182 -74.243470      1
# 9990          0855A            GY        2001.0  40.783662 -74.033567      1
# 9991          0916A            RD        2013.0  40.809377 -74.115553      0
# 9992          0951P            GY        2013.0  40.676889 -74.393024      0
# 9993          0101P         WHITE           0.0  40.658702 -74.213783      0
# 9994          0826A            WH        2007.0  40.743913 -74.200424      0
# 9995          0518P            BK        2009.0  40.676010 -74.120068      0
# 9996          0144P            RD           0.0  40.979049 -74.046964      0
# 9997          0740P            BK        2002.0  40.643126 -74.170207      0
# 9998          1119A            BL        1997.0  40.686111 -74.492095      0
# 9999          0410P         BLACK        2011.0  40.777803 -74.387246      0
#
#      DroneID
# 0     Drone2
# 1     Drone1
# 2     Drone2
# 3     Drone1
# 4     Drone2
# 5     Drone1
# 6     Drone3
# 7     Drone2
# 8     Drone4
# 9     Drone2
# 10    Drone3
# 11    Drone4
# 12    Drone4
# 13    Drone2
# 14    Drone1
# 15    Drone1
# 16    Drone3
# 17    Drone4
# 18    Drone3
# 19    Drone4
# 20    Drone1
# 21    Drone4
# 22    Drone2
# 23    Drone2
# 24    Drone2
# 25    Drone3
# 26    Drone2
# 27    Drone1
# 28    Drone2
# 29    Drone1
# ...      ...
# 9970  Drone3
# 9971  Drone1
# 9972  Drone4
# 9973  Drone3
# 9974  Drone3
# 9975  Drone4
# 9976  Drone1
# 9977  Drone3
# 9978  Drone2
# 9979  Drone1
# 9980  Drone4
# 9981  Drone3
# 9982  Drone3
# 9983  Drone3
# 9984  Drone2
# 9985  Drone1
# 9986  Drone3
# 9987  Drone3
# 9988  Drone4
# 9989  Drone1
# 9990  Drone1
# 9991  Drone4
# 9992  Drone1
# 9993  Drone1
# 9994  Drone1
# 9995  Drone3
# 9996  Drone1
# 9997  Drone3
# 9998  Drone4
# 9999  Drone1
#
# [10000 rows x 16 columns]

# %%
df1.to_csv('nyc-parking-ticket-2014.csv')
